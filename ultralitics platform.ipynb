# %% [markdown]
# <a href="https://colab.research.google.com/github/1900690/yolo-traking/blob/main/ultralitics%20platform.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.8/41.8 kB 3.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 67.3 MB/s eta 0:00:00
# ...

# %%
# 1. Jupyter環境でのasyncioの衝突を防ぐライブラリをインストールして適用
# !pip install -q nest_asyncio
import nest_asyncio
nest_asyncio.apply()

# --- ここから下は元のコードと同じです ---
import os

# APIキーを環境変数にセット
os.environ["ULTRALYTICS_API_KEY"] = "ul_047bf01e4de56d2a373aaacad650bbef204f13b9"

# 必須パッケージのインポートとトレーニングの実行
from ultralytics import YOLO

model = YOLO("ul://ultralytics/yolo26/yolo26n", task="detect")
model.train(
    data="ul://flamingo-flamingo/datasets/eggplant-flower-fruit",
    epochs=100,
    batch=-1,
    imgsz=640,
    project="flamingo-flamingo/eggplant-bbox",
)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# Ultralytics 8.4.84 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...
